# %% [markdown]
# # 常用的 DataFrame 操作
# * merge / transform
# * subset
# * groupby

# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# 設定 data_path
dir_data = 'D:\\Github\\2nd-ML100Days\\'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
app_train.head()
# Out:
# Path of read in data: D:\Github\2nd-ML100Days\application_train.csv
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
# ...

# %% [markdown]
#  作業
# 1. 請將 app_train 中的 CNT_CHILDREN 依照下列規則分為四組，並將其結果在原本的 dataframe 命名為 CNT_CHILDREN_GROUP
#     * 0 個小孩
#     * 有 1 - 2 個小孩
#     * 有 3 - 5 個小孩
#     * 有超過 5 個小孩
#
# 2. 請根據 CNT_CHILDREN_GROUP 以及 TARGET，列出各組的平均 AMT_INCOME_TOTAL，並繪製 baxplot
# 3. 請根據 CNT_CHILDREN_GROUP 以及 TARGET，對 AMT_INCOME_TOTAL 計算 [Z 轉換](https://en.wikipedia.org/wiki/Standard_score) 後的分數

# %%
#1
"""
Your code here
"""
cut_rule = [-1,0,2,5,app_train['CNT_CHILDREN'].max()] #[(-1~0),(0~2),(2~5),(5~max)]

app_train['CNT_CHILDREN_GROUP'] = pd.cut(app_train['CNT_CHILDREN'].values, cut_rule, include_lowest=True)
app_train['CNT_CHILDREN_GROUP'].value_counts()
# Out:
# (-1.001, 0.0]    215371
# (0.0, 2.0]        87868
# (2.0, 5.0]         4230
# (5.0, 19.0]          42
# Name: CNT_CHILDREN_GROUP, dtype: int64

# %%
#2-1
"""
Your code here
"""
grp = ['CNT_CHILDREN_GROUP'] #帶入規則

grouped_df = app_train.groupby(grp)['AMT_INCOME_TOTAL']
grouped_df.mean()
# Out:
# CNT_CHILDREN_GROUP
# (-1.001, 0.0]    166288.713566
# (0.0, 2.0]       174725.712648
# (2.0, 5.0]       173626.303191
# (5.0, 19.0]      147910.714286
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
#2-2
"""
Your code here
"""
plt_column = ['AMT_INCOME_TOTAL'] 
plt_by = ['CNT_CHILDREN_GROUP'] 

# column引數表示要繪製成箱形圖的資料，可以是一列或多列
# by引數表示分組依據
# sym：指定異常點的形狀，默認為+號顯示
# showfliers：是否顯示異常值，默認顯示
app_train.boxplot(column=plt_column, by = plt_by, showfliers = False, figsize=(12,12),sym='rd')
plt.suptitle('')
plt.show()

# %%
#3
"""
Your code here
"""

# z值=x值減去平均值，再除以標準差
#參考資源:https://blog.xuite.net/socimetry/twblog/176521440-16.%E5%B9%B3%E5%9D%87%E6%95%B8%E3%80%81%E6%A8%99%E6%BA%96%E5%B7%AE%E8%88%87z%E5%80%BC
app_train['AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET'] = grouped_df.apply(lambda x: (x - np.mean(x)) / (np.std(x)) ) 
app_train[['AMT_INCOME_TOTAL','AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET']].head(10)
# Out:
#    AMT_INCOME_TOTAL  AMT_INCOME_TOTAL_Z_BY_CHILDREN_GRP-TARGET
# 0          202500.0                                   0.345857
# 1          270000.0                                   0.990556
# 2           67500.0                                  -0.943540
# 3          135000.0                                  -0.298841
# 4          121500.0                                  -0.427781
# 5           99000.0                                  -0.642680
# 6          171000.0                                  -0.009056
# 7          360000.0                                   1.850154
# 8          112500.0                                  -0.513741
# 9          135000.0                                  -0.298841
