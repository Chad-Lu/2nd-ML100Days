# %% [markdown]
# #作業一:
# 1.你選的這組資料為何重要?我選擇的這組資料是Stanford Car數據分類資料 Kaggle網頁:https://www.kaggle.com/jutrera/stanford-car-dataset-by-classes-folder
# 2.資料從何而來?貢獻者:JesusUtrera 網頁:https://www.kaggle.com/jutrera 內容主要以圖片方式蒐集
# 3.蒐集而來的資料型態為何?為非結構化資料
# 4.這組資料想解決的問題如何評估?這個比賽需要分析出這是什麼車款。可以使用分類問題來評估。

# %% [markdown]
# #作業二:
# 1.核心問題為何? 我想要提升業績，但要如何從數據中分析出有用的數據。
# 2.資料從何而來? 數據需要從實際的載客車隊中提供。 可以分析顧客的搭車距離、平均費用、顧客類型、付款方式等等。
# 3.蒐集而來的資料型態為何? 為結構化資料
# 4.其如何評估?我想可以從數據中分析顧客的行為、喜好等等，可以用迴歸問題方式評估。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    #abs()絕對值
    #sum()加總
    #len()長度
    mse = MSE = sum(abs(y - yp))*w / len(y)
    return mse
    
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 40.833
# The Mean absolute error is 13.611
